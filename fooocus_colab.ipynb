# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# Collecting pygit2==1.15.1
#   Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pygit2==1.15.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (2.22)
# Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 68.5 MB/s eta 0:00:00
# Installing collected packages: pygit2
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.0
#     Uninstalling pygit2-1.18.0:
#       Successfully uninstalled pygit2-1.18.0
# Successfully installed pygit2-1.15.1
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Total 6725 (delta 0), reused 0 (delta 0), pack-reused 6725 (from 1)
# Receiving objects: 100% (6725/6725), 33.33 MiB | 11.67 MiB/s, done.
# Resolving deltas: 100% (3855/3855), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 64.4MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 33.6MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 298MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:00<00:00, 379MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_v8Rundiffusion.safetensors" to /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
#
# 100% 6.62G/6.62G [00:45<00:00, 155MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100% 47.3M/47.3M [00:00<00:00, 387MB/s]
# Total VRAM 15095 MB, total RAM 12978 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# Running on local URL:  http://127.0.0.1:7865
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# model_type EPS
# UNet ADM Dimension 2816
# Running on public URL: https://e96ea61f8500405548.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# 2025-07-06 06:16:18.935923: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751782578.960161    2340 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751782578.968432    2340 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-06 06:16:18.985769: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 1341
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://e96ea61f8500405548.gradio.live
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/model_base_caption_capfilt_large.pth" to /content/Fooocus/models/clip_vision/model_base_caption_capfilt_large.pth
#
# 100% 855M/855M [00:07<00:00, 113MB/s]
# load checkpoint from /content/Fooocus/models/clip_vision/model_base_caption_capfilt_large.pth
# Requested to load BLIP_Decoder
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.31 seconds
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/gradio/routes.py", line 488, in run_predict
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/gradio/blocks.py", line 1431, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/gradio/blocks.py", line 1103, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/anyio/_backends/_asyncio.py", line 2470, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/anyio/_backends/_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/gradio/utils.py", line 707, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/webui.py", line 1070, in trigger_describe
#     describe_prompts.append(default_interrogator_photo(img))
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/extras/interrogate.py", line 52, in interrogate
#     gpu_image = transforms.Compose([
#                 ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torchvision/transforms/transforms.py", line 95, in __call__
#     img = t(img)
#           ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torchvision/transforms/transforms.py", line 137, in __call__
#     return F.to_tensor(pic)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional.py", line 142, in to_tensor
#     raise TypeError(f"pic should be PIL Image or ndarray. Got {type(pic)}")
# TypeError: pic should be PIL Image or ndarray. Got <class 'NoneType'>
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 2157853885558359415
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_upscaler_s409985e5.bin" to /content/Fooocus/models/upscale_models/fooocus_upscaler_s409985e5.bin
#
# 100% 32.1M/32.1M [00:00<00:00, 433MB/s]
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 0 - 0
# [Fooocus] Initializing ...
# [Fooocus] Image processing ...
# [Fooocus] Upscaling image from (1024, 1024) ...
# Upscaling image with shape (1024, 1024, 3) ...
# Image upscaled.
# [Fooocus] Saving image to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-07-06/log.html
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 19.81 seconds
# [Fooocus Model Management] Moving model(s) has taken 1.11 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 6704690838715940890
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 0 - 0
# [Fooocus] Initializing ...
# [Fooocus] Image processing ...
# [Fooocus] Upscaling image from (922, 1280) ...
# Upscaling image with shape (1280, 922, 3) ...
# Image upscaled.
# [Fooocus] Saving image to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-07-06/log.html
# Total time: 19.50 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 15085568657459356
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Image processing ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1156, 867)
# Preparation time: 0.00 seconds
# Using karras scheduler.
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 0.00 seconds
# Total time: 0.53 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1366422011444038174
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 18 - 9
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.19 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Fooocus] Upscaling image from (867, 1156) ...
# Upscaling image with shape (1156, 867, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.49 seconds
# Final resolution is (1728, 2312).
# [Parameters] Denoising Strength = 0.382
# [Parameters] Initial Latent shape: torch.Size([1, 4, 289, 216])
# Preparation time: 36.36 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 0.5689725279808044
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.63 seconds
# 100% 18/18 [01:30<00:00,  5.02s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.39 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-07-06/log.html
# Generating and saving time: 141.29 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 0.5689725279808044
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.58 seconds
# 100% 18/18 [01:29<00:00,  4.95s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-07-06/log.html
# Generating and saving time: 139.16 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 280.46 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 316.88 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.76 seconds
# Loaded preset: /content/Fooocus/presets/realistic.json
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticStockPhoto_v20.safetensors" to /content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors
#
#  62% 4.02G/6.46G [01:52<00:48, 54.6MB/s][Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 3902710782192169150
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Draped in a beautifully crafted bronze-colored sari adorned with intricate golden patterns, a woman exudes grace and confidence as she strikes a poised stance. Her long, dark hair cascades over her shoulders, framing a face that is serene yet captivating, accentuated by delicate gold jewelry, including earrings and a layered necklace. With a traditional bindi adorning her forehead and intricate henna designs decorating her arms, she embodies both cultural elegance and modern sophistication. The soft, neutral backdrop enhances the richness of her attire, creating a harmonious balance that draws the viewer’s attention. The overall mood radiates warmth and celebratory femininity, suggesting a moment rich with tradition and beauty, cinematic, epic, highly detailed
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion]
seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2123857736587524
# Requested to load SDXL
# Loading 1 new model
#  85% 5.48G/6.46G [02:52<00:43, 24.3MB/s][Fooocus Model Management] Moving model(s) has taken 0.74 seconds
#
#  86% 5.55G/6.46G [02:52<00:13, 71.0MB/s]
#   3% 1/30 [00:00<00:28,  1.01it/s]
#   7% 2/30 [00:01<00:27,  1.01it/s]
#  10% 3/30 [00:02<00:26,  1.01it/s]
#  13% 4/30 [00:03<00:25,  1.02it/s]
#  87% 5.59G/6.46G [02:57<00:57, 16.3MB/s]
#  88% 5.70G/6.46G [02:58<00:11, 73.9MB/s]
#  23% 7/30 [00:06<00:22,  1.00it/s]
#  27% 8/30 [00:07<00:21,  1.00it/s]
#  30% 9/30 [00:08<00:21,  1.00s/it]
#  33% 10/30 [00:09<00:19,  1.00it/s]
#  88% 5.72G/6.46G [03:04<01:06, 12.0MB/s]
#  90% 5.82G/6.46G [03:04<00:13, 50.5MB/s]
#  43% 13/30 [00:12<00:16,  1.01it/s]
#  47% 14/30 [00:13<00:15,  1.01it/s]
#  50% 15/30 [00:14<00:14,  1.01it/s]
#  53% 16/30 [00:15<00:13,  1.02it/s]
#  57% 17/30 [00:16<00:12,  1.01it/s]
#  92% 5.95G/6.46G [03:10<00:10, 54.3MB/s]
#  92% 5.97G/6.46G [03:10<00:08, 61.7MB/s]
#  67% 20/30 [00:19<00:09,  1.01it/s]
#  70% 21/30 [00:20<00:08,  1.01it/s]
#  73% 22/30 [00:21<00:07,  1.01it/s]
#  77% 23/30 [00:22<00:06,  1.01it/s]
#  94% 6.08G/6.46G [03:16<00:08, 46.7MB/s]
#  94% 6.11G/6.46G [03:16<00:06, 61.5MB/s]
#  87% 26/30 [00:25<00:03,  1.01it/s]
#  90% 27/30 [00:26<00:02,  1.01it/s]
#  93% 28/30 [00:27<00:01,  1.01it/s]
#  97% 29/30 [00:28<00:00,  1.01it/s]
# 100% 30/30 [00:29<00:00,  1.01it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
#  97% 6.25G/6.46G [03:23<00:03, 72.9MB/s][Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-07-06/log.html
# Generating and saving time: 36.75 seconds
# [Fooocus] Processing enhance ...
# Enhancement image time: 0.00 seconds
# Enhancement image time: 0.00 seconds
# Processing time (total): 82.53 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
#  97% 6.27G/6.46G [03:28<00:16, 12.2MB/s]Total time: 95.16 seconds
#  99% 6.39G/6.46G [03:29<00:01, 64.1MB/s][Fooocus Model Management] Moving model(s) has taken 1.11 seconds
# 100% 6.46G/6.46G [03:34<00:00, 32.3MB/s]
# Downloading: "https://huggingface.co/mashb1t/fav_models/resolve/main/fav/SDXL_FILM_PHOTOGRAPHY_STYLE_V1.safetensors" to /content/Fooocus/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_V1.safetensors
#
# 100% 870M/870M [00:30<00:00, 29.9MB/s]
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 528716389825184972
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Image processing ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1600, 1141)
# Preparation time: 0.00 seconds
# Using karras scheduler.
# [Fooocus] Processing enhance ...
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (1141, 1600) ...
# Upscaling image with shape (1600, 1141, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.25 seconds
# Final resolution is (1704, 2400).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.68 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Draped in a beautifully crafted bronze-colored sari adorned with intricate golden patterns, a woman exudes grace and confidence as she strikes a poised stance. Her long, dark hair cascades over her shoulders, framing a face that is serene yet captivating, accentuated by delicate gold jewelry, including earrings and a layered necklace. With a traditional bindi adorning her forehead and intricate henna designs decorating her arms, she embodies both cultural elegance and modern sophistication. The soft, neutral backdrop enhances the richness of her attire, creating a harmonious balance that draws the viewer’s attention. The overall mood radiates warmth and celebratory femininity, suggesting a moment rich with tradition and beauty, detailed, lush vibrant color background
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding negative #1 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 0.5689725279808044
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.17 seconds
# 100% 18/18 [01:31<00:00,  5.10s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/1 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-07-06/log.html
# Enhancement image time: 196.22 seconds
# Processing time (total): 196.22 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.86 seconds
# Total time: 198.40 seconds
